# %% [markdown]
# # CNN fashion mnist

# %%
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 数据集维度 N*H*W
train_images.shape, train_labels.shape, \
test_images.shape, test_labels.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# CNN用Conv2D，所以要加上一个维度channel
# 维度变成 N*H*W*C
train_images = train_images[..., tf.newaxis]
test_images = test_images[..., tf.newaxis]

train_images.shape, train_labels.shape, \
test_images.shape, test_labels.shape
# Out:
# ((60000, 28, 28, 1, 1), (60000,), (10000, 28, 28, 1, 1), (10000,))

# %%
# CNN 
cnn_model = tf.keras.Sequential()
cnn_model.add(tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
cnn_model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
cnn_model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
cnn_model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(tf.keras.layers.Flatten())
cnn_model.add(tf.keras.layers.Dense(256, activation='relu'))
cnn_model.add(tf.keras.layers.Dense(10, activation='softmax'))
cnn_model.summary()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-4-fbdfd797160a> in <module>
#       1 # CNN
#       2 cnn_model = tf.keras.Sequential()
# ----> 3 cnn_model.add(tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
#       4 cnn_model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
#       5 cnn_model.add(tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/sequential.py in add(self, layer)
#     183           # and create the node connecting the current layer
#     184           # to the input layer we just created.
# --> 185           layer(x)
#     186           set_inputs = True
#     187
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     837           # Build layer if applicable (if the `build` method has been
#     838           # overridden).
# --> 839           self._maybe_build(inputs)
#     840           cast_inputs = self._maybe_cast_inputs(inputs)
#     841
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2190         # operations.
#    2191         with tf_utils.maybe_init_scope(self):
# -> 2192           self.build(input_shapes)
#    2193       # We must set self.built since user defined build functions are not
#    2194       # constrained to set self.built.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/convolutional.py in build(self, input_shape)
#     160         constraint=self.kernel_constraint,
#     161         trainable=True,
# --> 162         dtype=self.dtype)
#     163     if self.use_bias:
#     164       self.bias = self.add_weight(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     542         collections=collections_arg,
#     543         synchronization=synchronization,
# --> 544         aggregation=aggregation)
#     545     backend.track_variable(variable)
#     546
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     742         dtype=dtype,
#     743         initializer=initializer,
# --> 744         **kwargs_for_getter)
#     745
#     746     # If we set an initializer and the variable processed it, tracking will not
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     138       synchronization=synchronization,
#     139       aggregation=aggregation,
# --> 140       shape=variable_shape if variable_shape else None)
#     141
#     142
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     256   def __call__(cls, *args, **kwargs):
#     257     if cls is VariableV1:
# --> 258       return cls._variable_v1_call(*args, **kwargs)
#     259     elif cls is Variable:
#     260       return cls._variable_v2_call(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     217         synchronization=synchronization,
#     218         aggregation=aggregation,
# --> 219         shape=shape)
#     220
#     221   def _variable_v2_call(cls,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py in <lambda>(**kwargs)
#     195                         shape=None):
#     196     """Call on Variable class. Useful to force the signature."""
# --> 197     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     198     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     199       previous_getter = _make_getter(getter, previous_getter)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2594         synchronization=synchronization,
#    2595         aggregation=aggregation,
# -> 2596         shape=shape)
#    2597   else:
#    2598     return variables.RefVariable(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     260       return cls._variable_v2_call(*args, **kwargs)
#     261     else:
# --> 262       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     263
#     264
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1404           aggregation=aggregation,
#    1405           shape=shape,
# -> 1406           distribute_strategy=distribute_strategy)
#    1407
#    1408   def _init_from_args(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1535           with ops.name_scope("Initializer"), device_context_manager(None):
#    1536             initial_value = ops.convert_to_tensor(
# -> 1537                 initial_value() if init_from_fn else initial_value,
#    1538                 name="initial_value", dtype=dtype)
#    1539           if shape is not None:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer_utils.py in <lambda>()
#     118           (type(init_ops.Initializer), type(init_ops_v2.Initializer))):
#     119         initializer = initializer()
# --> 120       init_val = lambda: initializer(shape, dtype=dtype)
#     121       variable_dtype = dtype.base_dtype
#     122   if use_resource is None:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops_v2.py in __call__(self, shape, dtype)
#     423     else:
#     424       limit = math.sqrt(3.0 * scale)
# --> 425       return self._random_generator.random_uniform(shape, -limit, limit, dtype)
#     426
#     427   def get_config(self):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops_v2.py in random_uniform(self, shape, minval, maxval, dtype)
#     786       op = random_ops.random_uniform
#     787     return op(
# --> 788         shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#     789
#     790   def truncated_normal(self, shape, mean, stddev, dtype):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     262     maxval = 1
#     263   with ops.name_scope(name, "random_uniform", [shape, minval, maxval]) as name:
# --> 264     shape = tensor_util.shape_tensor(shape)
#     265     minval = ops.convert_to_tensor(minval, dtype=dtype, name="min")
#     266     maxval = ops.convert_to_tensor(maxval, dtype=dtype, name="max")
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/tensor_util.py in shape_tensor(shape)
#     979       # not convertible to Tensors becasue of mixed content.
#     980       shape = tuple(map(tensor_shape.dimension_value, shape))
# --> 981   return ops.convert_to_tensor(shape, dtype=dtype, name="shape")
#     982
#     983
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype, dtype_hint)
#    1192   preferred_dtype = deprecation.deprecated_argument_lookup(
#    1193       "dtype_hint", dtype_hint, "preferred_dtype", preferred_dtype)
# -> 1194   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1195
#    1196
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1250       name=name,
#    1251       preferred_dtype=dtype_hint,
# -> 1252       as_ref=False)
#    1253
#    1254
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accepted_result_types)
#    1305
#    1306     if ret is None:
# -> 1307       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1308
#    1309     if ret is NotImplemented:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     315                                          as_ref=False):
#     316   _ = as_ref
# --> 317   return constant(v, dtype=dtype, name=name)
#     318
#     319
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     256   """
#     257   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 258                         allow_broadcast=True)
#     259
#     260
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     264   ctx = context.context()
#     265   if ctx.executing_eagerly():
# --> 266     t = convert_to_eager_tensor(value, ctx, dtype)
#     267     if shape is None:
#     268       return t
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      93     except AttributeError:
#      94       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ---> 95   ctx.ensure_initialized()
#      96   return ops.EagerTensor(value, ctx.device_name, dtype)
#      97
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/context.py in ensure_initialized(self)
#     489         if self._default_is_async == ASYNC:
#     490           pywrap_tensorflow.TFE_ContextOptionsSetAsync(opts, True)
# --> 491         context_handle = pywrap_tensorflow.TFE_NewContext(opts)
#     492       finally:
#     493         pywrap_tensorflow.TFE_DeleteContextOptions(opts)
#
# InvalidArgumentError: device CUDA:5 not supported by XLA service
# 	while setting up XLA_GPU_JIT device number 5

# %%
cnn_model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# with tf.device('/GPU:3'):
cnn_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

session.close()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
#    32/60000 [..............................] - ETA: 1:00:23
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-18-d830850dadf4> in <module>
#       8
#       9 # with tf.device('/GPU:3'):
# ---> 10 cnn_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))
#      11 session.close()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     764         max_queue_size=max_queue_size,
#     765         workers=workers,
# --> 766         use_multiprocessing=use_multiprocessing)
#     767
#     768   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     331                 mode=ModeKeys.TRAIN,
#     332                 training_context=training_context,
# --> 333                 total_epochs=epochs)
#     334             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     335
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     551
#     552     tracing_count = self._get_tracing_count()
# --> 553     result = self._call(*args, **kwds)
#     554     if tracing_count == self._get_tracing_count():
#     555       self._call_counter.called_without_tracing()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     581       # In this case we have created variables on the first call, so we run the
#     582       # defunned version which is guaranteed to never create variables.
# --> 583       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     584     elif self._stateful_fn is not None:
#     585       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2293     """Calls a graph function specialized to the inputs."""
#    2294     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2295     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2296
#    2297   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1554          if isinstance(t, (ops.Tensor,
#    1555                            resource_variable_ops.BaseResourceVariable))),
# -> 1556         self.captured_inputs)
#    1557
#    1558   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1635       # No tape is watching; skip to running the function.
#    1636       return self._build_call_outputs(self._inference_function.call(
# -> 1637           ctx, args, cancellation_manager=cancellation_manager))
#    1638     forward_backward = self._select_forward_and_backward_functions(
#    1639         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495               inputs=args,
#     496               attrs=("executor_type", executor_type, "config_proto", config),
# --> 497               ctx=ctx)
#     498         else:
#     499           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# UnknownError: 2 root error(s) found.
#   (0) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node sequential/conv2d/Conv2D (defined at <ipython-input-6-c15258d0e576>:9) ]]
#   (1) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node sequential/conv2d/Conv2D (defined at <ipython-input-6-c15258d0e576>:9) ]]
# 	 [[GroupCrossDeviceControlEdges_0/Adam/Adam/Const/_19]]
# 0 successful operations.
# 0 derived errors ignored.
# 	Encountered when executing an operation using EagerExecutor. This error cancels all future operations and poisons their output tensors. [Op:__inference_distributed_function_1090]
#
# Function call stack:
# distributed_function -> distributed_function

# %%
# 保存模型
save_model_path = './fashion_mnist/fashion_mnist_cnn_model.h5'
cnn_model.save(save_model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a53288de5b9a> in <module>
#       1 # 保存模型
#       2 save_model_path = './fashion_mnist/fashion_mnist_cnn_model.h5'
# ----> 3 cnn_model.save(save_model_path)
#       4
#       5 # 重新加载模型
#
# NameError: name 'cnn_model' is not defined

# %%
import tensorflow as tf

# 加载测试数据
_, (test_x, text_y) = tf.keras.datasets.fashion_mnist.load_data()
test_x = test_x[..., tf.newaxis]

# 重新加载模型
save_model_path = './fashion_mnist/fashion_mnist_cnn_model.h5'
loaded_model = tf.keras.models.load_model(save_model_path)

# 测试
loss, acc = loaded_model.evaluate(test_images, test_labels, verbose=2)
print('fashion mnist cnn, loss is {:f}, accuracy is {:5.2%}'.format(acc))
# Out:
# 32/1 - 0s
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-8-7ccb67fd29c4> in <module>
#      10
#      11 # 测试
# ---> 12 loss, acc = loaded_model.evaluate(test_images, test_labels, verbose=2)
#      13 print('fashion mnist cnn, loss is {:f}, accuracy is {:5.2%}'.format(acc))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     869         max_queue_size=max_queue_size,
#     870         workers=workers,
# --> 871         use_multiprocessing=use_multiprocessing)
#     872
#     873   def predict(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in evaluate(self, model, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     480         sample_weight=sample_weight, steps=steps, callbacks=callbacks,
#     481         max_queue_size=max_queue_size, workers=workers,
# --> 482         use_multiprocessing=use_multiprocessing, **kwargs)
#     483
#     484   def predict(self, model, x, batch_size=None, verbose=0, steps=None,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     465               mode=mode,
#     466               training_context=training_context,
# --> 467               total_epochs=1)
#     468           cbks.make_logs(model, epoch_logs, result, mode)
#     469
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     551
#     552     tracing_count = self._get_tracing_count()
# --> 553     result = self._call(*args, **kwds)
#     554     if tracing_count == self._get_tracing_count():
#     555       self._call_counter.called_without_tracing()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     620               *args, **kwds)
#     621       # If we did not create any variables the trace we have is good enough.
# --> 622       return self._concrete_stateful_fn._filtered_call(canon_args, canon_kwds)  # pylint: disable=protected-access
#     623
#     624     def fn_with_cond(*inner_args, **inner_kwds):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1554          if isinstance(t, (ops.Tensor,
#    1555                            resource_variable_ops.BaseResourceVariable))),
# -> 1556         self.captured_inputs)
#    1557
#    1558   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1635       # No tape is watching; skip to running the function.
#    1636       return self._build_call_outputs(self._inference_function.call(
# -> 1637           ctx, args, cancellation_manager=cancellation_manager))
#    1638     forward_backward = self._select_forward_and_backward_functions(
#    1639         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495               inputs=args,
#     496               attrs=("executor_type", executor_type, "config_proto", config),
# --> 497               ctx=ctx)
#     498         else:
#     499           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# UnknownError:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node sequential/conv2d/Conv2D (defined at <ipython-input-8-7ccb67fd29c4>:12) ]]
# 	Encountered when executing an operation using EagerExecutor. This error cancels all future operations and poisons their output tensors. [Op:__inference_distributed_function_2109]
#
# Function call stack:
# distributed_function
