# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is
# Out:
# Text(0.5, 0.98, 'No axes on this figure')

# %%
# 注意，这里对应的x就是元素的index
plt.plot([1, 2, 3, 4])
plt.show()

# %%
# 画点
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# 同一张图上画多个图像
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# 当数据中心颜色和大小都不相同时，用scatter画图
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
fig, axes = plt.subplots(2, 3)
axes = axes.flatten()
x = np.linspace(-8, 8, 100)
for i, ax in enumerate(axes):
    ax.set_xlim(-8, 8)
    ax.set_ylim(-8, 8)
    ax.set_xlabel('{:s}'.format('x'))
    ax.set_ylabel('{:s}'.format('y'))
    ax.plot(x, (i+1)*np.sin((i+1)*x))
#     ax.axis('off')
    ax.axis('equal')
plt.show()

# %%
t = np.linspace(-2.*np.pi, 2.*np.pi, 128)
fig, ax = plt.subplots()
ax.plot(t, np.sin(t), 'C1', label='C1')
ax.plot(t, np.cos(t), 'C2', label='C2')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image = mpimg.imread('../lena.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')
plt.show()
